# %%
import pandas as pd

# %%
#Load the data using Pandas
df=pd.read_csv('job-market-1.csv')

# %%
df
# Out:
#                Id                                              Title  \
# 0      37404348.0                           Casual Stock Replenisher
# 1      37404337.0                           Casual Stock Replenisher
# 2      37404356.0  RETAIL SALES SUPERSTARS and STYLISTS Wanted - ...
# 3      37404330.0                              Team member - Belrose
# 4      37404308.0  Business Banking Contact Centre Specialist, Ni...
# ...           ...                                                ...
# 40784         NaN                                                NaN
# 40785         NaN                                                NaN
# 40786         NaN                                                NaN
# 40787         NaN                                                NaN
# 40788         NaN                                                NaN
#
#                                               Company  \
# 0                                         Aldi Stores
# ...

# %%
#Visualize top 10 first rows
df.head(10)
# Out:
#            Id                                              Title  \
# 0  37404348.0                           Casual Stock Replenisher
# 1  37404337.0                           Casual Stock Replenisher
# 2  37404356.0  RETAIL SALES SUPERSTARS and STYLISTS Wanted - ...
# 3  37404330.0                              Team member - Belrose
# 4  37404308.0  Business Banking Contact Centre Specialist, Ni...
# 5  37404307.0  Business Banking Contact Centre Specialist, Ni...
# 6  37404355.0               Casual Café All-rounder in Semaphore
# 7  37404350.0           Casual Café All-rounder in Woolloongabba
# 8  37404301.0                                       Telemarketer
# 9  37404286.0                       Casual Dish Hand in Brighton
#
#                                           Company                      Date  \
# 0                                     Aldi Stores  2018-10-07T00:00:00.000Z
# 1                                     Aldi Stores  2018-10-07T00:00:00.000Z
# ...

# %%
df.isnull()
# Out:
#           Id  Title  Company   Date  Location   Area  Classification  \
# 0      False  False    False  False     False  False           False
# 1      False  False    False  False     False   True           False
# 2      False  False    False  False     False  False           False
# 3      False  False    False  False     False   True           False
# 4      False  False    False  False     False  False           False
# ...      ...    ...      ...    ...       ...    ...             ...
# 40784   True   True     True   True      True   True            True
# 40785   True   True     True   True      True   True            True
# 40786   True   True     True   True      True   True            True
# 40787   True   True     True   True      True   True            True
# 40788   True   True     True   True      True   True            True
#
#        SubClassification  Requirement  FullDescription  LowestSalary  \
# ...

# %%
df.dropna()
# Out:
#                Id                                         Title  \
# 121    37404238.0                          Fabricator/Installer
# 122    37404195.0                                   Boilermaker
# 125    37404288.0  Casual Childcare Positions  | Bondi Junction
# 126    37404267.0                                    Technician
# 127    37404230.0                              Systems Engineer
# ...           ...                                           ...
# 10091  37388929.0                            Lead Kit Assembler
# 10094  37388912.0                           Executive Assistant
# 10096  37388901.0                  Receptionist / Administrator
# 10097  37388898.0     INTERNATIONAL WHOLESALE TRAVEL CONSULTANT
# 10098  37388893.0               Customer Service Representative
#
#                            Company                      Date   Location  \
# 121      WORKPLACE ACCESS & SAFETY  2018-10-07T00:00:00.000Z  Melbourne
# ...
